# %% [markdown]
# # Skewness
# Skewness is the measure of the asymmetry of an ideally symmetric probability distribution and is given by the third standardized moment. If that sounds way too complex, don’t worry! Let me break it down for you.
#
# In simple words, skewness is the measure of how much the probability distribution of a random variable deviates from the normal distribution. Now, you might be thinking – why am I talking about normal distribution here?

# %% [markdown]
# ![skewnessformula.jpg](attachment:skewnessformula.jpg)

# %% [markdown]
# Well, the normal distribution is the probability distribution without any skewness. You can look at the image below which shows symmetrical distribution that’s basically a normal distribution and you can see that it is symmetrical on both sides of the dashed line. Apart from this, there are two types of skewness:
#
# 1. Positive Skewness
# 2. Negative Skewness

# %% [markdown]
# ![skewness.jpg](attachment:skewness.jpg)

# %% [markdown]
# ###### Why is Skewness Important?
# Now, we know that the skewness is the measure of asymmetry and its types are distinguished by the side on which the tail of probability distribution lies. But why is knowing the skewness of the data important?
#
# ###### First, linear models work on the assumption that the distribution of the independent variable and the target variable are similar. Therefore, knowing about the skewness of data helps us in creating better linear models.
#
# Secondly, let’s take a look at the below distribution. It is the distribution of horsepower of cars:

# %% [markdown]
# ![skewexample.jpg](attachment:skewexample.jpg)

# %% [markdown]
# You can clearly see that the above distribution is positively skewed. Now, let’s say you want to use this as a feature for the model which will predict the mpg (miles per gallon) of a car.
#
# ###### Since our data is positively skewed here, it means that it has a higher number of data points having low values, i.e., cars with less horsepower. So when we train our model on this data, it will perform better at predicting the mpg of cars with lower horsepower as compared to those with higher horsepower.
#
# Also, skewness tells us about the direction of outliers. You can see that our distribution is positively skewed and most of the outliers are present on the right side of the distribution.
#
# ###### Note:
# The skewness does not tell us about the number of outliers. It only tells us the direction.
# Now we know why skewness is important, let’s understand the distributions which I showed you earlier.
#
#
#
# #### What is Symmetric/Normal Distribution?
#
# ![1.jpg](attachment:1.jpg)
#
# Yes, we’re back again with the normal distribution. It is used as a reference for determining the skewness of a distribution. As I mentioned earlier, the ideal normal distribution is the probability distribution with almost no skewness. It is nearly perfectly symmetrical. Due to this, the value of skewness for a normal distribution is zero.
#
# But, why is it nearly perfectly symmetrical and not absolutely symmetrical?
#
# That’s because, in reality, no real word data has a perfectly normal distribution. Therefore, even the value of skewness is not exactly zero; it is nearly zero. Although the value of zero is used as a reference for determining the skewness of a distribution.
#
# You can see in the above image that the same line represents the mean, median, and mode. It is because the mean, median, and mode of a perfectly normal distribution are equal.
#
# So far, we’ve understood the skewness of normal distribution using a probability or frequency distribution. Now, let’s understand it in terms of a boxplot because that’s the most common way of looking at a distribution in the data science space.

# %% [markdown]
# ![2.jpg](attachment:2.jpg)
#
# The above image is a boxplot of symmetric distribution. You’ll notice here that the distance between Q1 and Q2 and Q2 and Q3 is equal i.e.:

# %% [markdown]
# ![3.jpg](attachment:3.jpg)
#
# But that’s not enough for concluding if a distribution is skewed or not. We also take a look at the length of the whisker; if they are equal, then we can say that the distribution is symmetric, i.e. it is not skewed.
#
# Now that we’ve discussed the skewness in the normal distribution, it’s time to learn about the two types of skewness which we discussed earlier. Let’s start with positive skewness.

# %% [markdown]
# #### Understanding Positively Skewed Distribution

# %% [markdown]
# ![4.jpg](attachment:4.jpg)

# %% [markdown]
# A positively skewed distribution is the distribution with the tail on its right side. The value of skewness for a positively skewed distribution is greater than zero. As you might have already understood by looking at the figure, the value of mean is the greatest one followed by median and then by mode.
#
# So why is this happening?
#
# Well, the answer to that is that the skewness of the distribution is on the right; it causes the mean to be greater than the median and eventually move to the right. Also, the mode occurs at the highest frequency of the distribution which is on the left side of the median. Therefore, mode < median < mean.

# %% [markdown]
# ![5.jpg](attachment:5.jpg)

# %% [markdown]
# In the above boxplot, you can see that Q2 is present nearer to Q1. This represents a positively skewed distribution. In terms of quartiles, it can be given by:

# %% [markdown]
# ![6.jpg](attachment:6.jpg)
#
# In this case, it was very easy to tell if the data is skewed or not. But what if we have something like this:

# %% [markdown]
# ![7.jpg](attachment:7.jpg)
#
# Here, Q2-Q1 and Q3-Q2 are equal and yet the distribution is positively skewed. The keen-eyed among you will have noticed the length of the right whisker is greater than the left whisker. From this, we can conclude that the data is positively skewed.
#
# So, the first step is always to check the equality of Q2-Q1 and Q3-Q2. If that is found equal, then we look for the length of whiskers.
#
#
#
# ### Understanding Negatively Skewed Distribution

# %% [markdown]
# ![8.jpg](attachment:8.jpg)
#
# As you might have already guessed, a negatively skewed distribution is the distribution with the tail on its left side. The value of skewness for a negatively skewed distribution is less than zero. You can also see in the above figure that the mean < median < mode.

# %% [markdown]
# ![9.jpg](attachment:9.jpg)
#
# In the boxplot, the relationship between quartiles for a negative skewness is given by:

# %% [markdown]
# ![10.jpg](attachment:10.jpg)
#
# Similar to what we did earlier, if Q3-Q2 and Q2-Q1 are equal, then we look for the length of whiskers. And if the length of the left whisker is greater than that of the right whisker, then we can say that the data is negatively skewed.

# %% [markdown]
# ![11.jpg](attachment:11.jpg)

# %% [markdown]
# ### Important:-
# 1. skewness = 0 : normally distributed.
# 2. skewness > 0 : more weight in the left tail of the distribution.
# 3. skewness < 0 : more weight in the right tail of the distribution.

# %%
from scipy.stats import skew 
import numpy as np  
import pylab as p  
  
x1 = np.linspace( -5, 5, 1000 ) 
y1 = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x1)**2  ) 
p.plot(x1, y1, '*') 
  
print( '\nSkewness for data : ', skew(y1)) 
if skew(y1) > 0 :
    print("Positively Skewed")
elif skew(y1) < 0 :
    print("Negatively skewed")
else:
    print("Bell shaped curve")
# Out:
# Skewness for data :  1.1108237139164436
# Positively Skewed

# %%
from pandas import DataFrame
df = DataFrame (y1,columns=['Column'])
desc = df.describe()
print(desc)
# For positively skewed condition is q3-q2 > q2-q1
if (desc['Column']['75%'] - desc['Column']['50%']) > (desc['Column']['50%'] - desc['Column']['25%']) :
    print("Positively skewed")
elif (desc['Column']['75%'] - desc['Column']['50%']) < (desc['Column']['50%'] - desc['Column']['25%']) :
    print("negatively skewed")
else:
    print("Symmatric or bell shaped curve")
# Out:
#             Column
# count  1000.000000
# mean      0.099900
# std       0.134980
# min       0.000001
# 25%       0.000351
# 50%       0.017420
# 75%       0.181794
# max       0.398937
# Positively skewed

# %%
import seaborn as sns
ax = sns.boxplot(x=y1)
print("From Box plot we can conclude that data is positively skewed")
# Out:
# From Box plot we can conclude that data is positively skewed

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
df1 = DataFrame(x)
print(df1.describe())
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()
# Out:
#                   0
# count  1.000000e+02
# mean   1.065814e-16
# std    1.758272e+00
# min   -3.000000e+00
# 25%   -1.500000e+00
# 50%    0.000000e+00
# 75%    1.500000e+00
# max    3.000000e+00

# %% [markdown]
# #### How Do We Transform Skewed Data?
# Since you know how much the skewed data can affect our machine learning model’s predicting capabilities, it is better to transform the skewed data to normally distributed data. Here are some of the ways you can transform your skewed data:
#
# 1. Power Transformation
# 2. Log Transformation
# 3. Exponential Transformation
#
# ###### Note:
# The selection of transformation depends on the statistical characteristics of the data.

# %%
import pandas as pd
data = pd.read_csv("Dataset/iris.csv")
desc = data.describe()
print(desc)
print(desc['petal.length']['count'])
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
# 150.0

# %%
import seaborn as sns
sns.boxplot(data['petal.length'])
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# ### 1. Normalization

# %% [markdown]
# Skewed data is cumbersome and common. It’s often desirable to transform skewed data and to convert it into values between 0 and 1.
# Standard functions used for such conversions include Normalization, the Sigmoid, Log, Cube Root and the Hyperbolic Tangent. It all depends on what one is trying to accomplish.
#
# Removing outliers is an option, but not one that I want to use here. My end goal is to build a machine learning algorithm to predict whether a given review is helpful, so reviews with the most helpful votes are indispensable.
#
# I will use the functions listed above to transform the data, explaining pros and cons along the way. As with most data science, there is no correct function. It depends on the data, and the goal of the analyst.
#
# Normalization converts all data points to decimals between 0 and 1. If the min is 0,
# simply divide each point by the max.
#
# ##### If the min is not 0, subtract the min from each point, and then divide by the min-max difference.
#
# The following function includes both cases.

# %%
def normalize(column):
    upper = column.max()
    lower = column.min()
    y = (column - lower)/(upper-lower)
    return y
helpful_normalized = normalize(data['petal.length'])
helpful_normalized.describe()
# Out:
# count    150.000000
# mean       0.467458
# std        0.299203
# min        0.000000
# 25%        0.101695
# 50%        0.567797
# 75%        0.694915
# max        1.000000
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_normalized)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# ### 2. Sigmoid function

# %% [markdown]
# ![sigmoid.png](attachment:sigmoid.png)
#
# It’s a beautifully smooth curve that guarantees a 0 to 1 range. Let’s see how it performs on df.Helpful_Votes.

# %%
import numpy as np
def sigmoid(x):
    e = np.exp(1)
    y = 1/(1+e**(-x))
    return y
helpful_sigmoid = sigmoid(data['petal.length'])
helpful_sigmoid.describe()
# Out:
# count    150.000000
# mean       0.930155
# std        0.086548
# min        0.731059
# 25%        0.832018
# 50%        0.987242
# 75%        0.993940
# max        0.998993
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_sigmoid)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# A definite improvement. The new data is between 0 and 1 as expected, but the min is 0.5. This makes sense when looking at the graph as there are no negative values when tallying votes.
#
# #### 3. Log Function

# %%
helpful_log = np.log(data['petal.length'])
helpful_log.describe()
# Out:
# count    150.000000
# mean       1.175038
# std        0.590125
# min        0.000000
# 25%        0.470004
# 50%        1.470110
# 75%        1.629241
# max        1.931521
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_log)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# #### 4. Log Function + 1 Normalized

# %%
helpful_log_normalized = normalize(helpful_log)
helpful_log_normalized.describe()
# Out:
# count    150.000000
# mean       0.608349
# std        0.305523
# min        0.000000
# 25%        0.243333
# 50%        0.761115
# 75%        0.843501
# max        1.000000
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_log_normalized)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# This looks very reasonable. The log function plus normalization is an excellent way to transform skewed data if the results can still be skewed. There is, however, one major drawback in this case.

# %% [markdown]
# #### 5. Cube Root

# %%
helpful_cube_root = data['petal.length']**(1/3)
helpful_cube_root.describe()
# Out:
# count    150.000000
# mean       1.506956
# std        0.277692
# min        1.000000
# 25%        1.169607
# 50%        1.632388
# 75%        1.721301
# max        1.903778
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_cube_root)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# #### 6. Cube Root Normalized

# %%
helpful_cube_root_normalized = normalize(helpful_cube_root)
helpful_cube_root_normalized.describe()
# Out:
# count    150.000000
# mean       0.560930
# std        0.307257
# min        0.000000
# 25%        0.187664
# 50%        0.699716
# 75%        0.798095
# max        1.000000
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_cube_root_normalized)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# #### 7. Log Max Root

# %%
log_max = np.log(data['petal.length'].max())
helpful_log_max_root = data['petal.length']**(1/log_max)
helpful_log_max_root.describe()
# Out:
# count    150.000000
# mean       1.918552
# std        0.526541
# min        1.000000
# 25%        1.275494
# 50%        2.140699
# 75%        2.324491
# max        2.718282
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_log_max_root)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# #### 8. Log Max Root Normalized

# %%
helpful_log_max_root_normalized = normalize(helpful_log_max_root)
helpful_log_max_root_normalized.describe()
# Out:
# count    150.000000
# mean       0.534576
# std        0.306434
# min        0.000000
# 25%        0.160331
# 50%        0.663861
# 75%        0.770823
# max        1.000000
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_log_max_root_normalized)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# #### 9. Hyperbolic Tangent

# %%
helpful_hyperbolic_tangent = np.tanh(data['petal.length'])
helpful_hyperbolic_tangent.describe()
# Out:
# count    150.000000
# mean       0.964057
# std        0.054551
# min        0.761594
# 25%        0.921669
# 50%        0.999665
# 75%        0.999926
# max        0.999998
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_hyperbolic_tangent)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# #### 10. Percentile Linearization

# %%
size = len(data['petal.length'])-1
helpful_percentile_linearization = data['petal.length'].rank(method='min').apply(lambda x: (x-1)/size)
helpful_percentile_linearization.describe()
# Out:
# count    150.000000
# mean       0.483848
# std        0.298449
# min        0.000000
# 25%        0.248322
# 50%        0.496644
# 75%        0.724832
# max        1.000000
# Name: petal.length, dtype: float64

# %%
sns.boxplot(helpful_percentile_linearization)
# Out:
# /home/himanshugoyal/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal.length'>

# %% [markdown]
# Since from above box plot we can conclude that this box plot is very much accurate for petal.length.

# %% [markdown]
#     -----------------------------------------------------------------------------

# %% [markdown]
# # Kurtosis
# Kurtosis is all about the tails of the distribution — not the peakedness or flatness. It is used to describe the extreme values in one versus the other tail. It is actually the measure of outliers present in the distribution . High kurtosis in a data set is an indicator that data has heavy tails or outliers.
#
# #### High kurtosis
# High kurtosis in a data set is an indicator that data has heavy tails or outliers. If there is a high kurtosis, then, we need to investigate why do we have so many outliers. It indicates a lot of things, maybe wrong data entry or other things. Investigate!
#
# #### Low kurtosis
# Low kurtosis in a data set is an indicator that data has light tails or lack of outliers. If we get low kurtosis(too good to be true), then also we need to investigate and trim the dataset of unwanted results.
#
# #### Mesokurtic:
# This distribution has kurtosis statistic similar to that of the normal distribution. It means that the extreme values of the distribution are similar to that of a normal distribution characteristic. This definition is used so that the standard normal distribution has a kurtosis of three.
#
# #### Leptokurtic (Kurtosis > 3):
# Distribution is longer, tails are fatter. Peak is higher and sharper than Mesokurtic, which means that data are heavy-tailed or profusion of outliers.
# Outliers stretch the horizontal axis of the histogram graph, which makes the bulk of the data appear in a narrow (“skinny”) vertical range, thereby giving the “skinniness” of a leptokurtic distribution.
#
# #### Platykurtic: (Kurtosis < 3):
# Distribution is shorter, tails are thinner than the normal distribution. The peak is lower and broader than Mesokurtic, which means that data are light-tailed or lack of outliers.
# The reason for this is because the extreme values are less than that of the normal distribution.

# %%
# Graph using numpy.linspace()  
# finding kurtosis 
  
from scipy.stats import kurtosis 
import numpy as np  
import pylab as p  
  
x1 = np.linspace( -5, 5, 1000 ) 
y1 = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x1)**2  ) 
  
p.plot(x1, y1, '*') 
  
#Scipy.kurtosis always calculate the excess kutosis, so add 3 to get the accurate kurtosis.
    
print( '\nKurtosis for normal distribution :', kurtosis(y1)+3) 
  
print( '\nKurtosis for normal distribution :',  
      kurtosis(y1, fisher = False)+3) 
  
print( '\nKurtosis for normal distribution :',  
      kurtosis(y1, fisher = True)+3)
# Out:
# Kurtosis for normal distribution : 2.692606912257793
#
# Kurtosis for normal distribution : 5.6926069122577925
#
# Kurtosis for normal distribution : 2.692606912257793
